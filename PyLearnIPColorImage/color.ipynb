# %%
import math
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import ImageFont, ImageDraw, Image

# %% [markdown]
# Color to Gray

# %%
def color2gray(image):
    result = np.mean(image, axis=2)
    return result

image_girl = cv2.imread('input/girl.jpg')
image_girl_gray = color2gray(image_girl)
plt.imshow(image_girl_gray, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# rainbow

# %%
rainbow = np.ones((500,1000,3), dtype=np.uint8)*255
for i in range(rainbow.shape[0]):
    for j in range(0, rainbow.shape[1]//2):
        radius = math.sqrt(i*i + j*j) + 3
        if 150 <= radius < 200:
            rainbow[rainbow.shape[1]//2 - i - 1,[rainbow.shape[1]//2 - j - 1,rainbow.shape[1]//2 + j - 1 ]] = [148,0,211]
        if 200 <= radius < 250:
            rainbow[rainbow.shape[1]//2 - i - 1,[rainbow.shape[1]//2 - j - 1,rainbow.shape[1]//2 + j - 1 ]] = [75,0,130]
        if 250 <= radius < 300:
            rainbow[rainbow.shape[1]//2 - i - 1,[rainbow.shape[1]//2 - j - 1,rainbow.shape[1]//2 + j - 1 ]] = [0,0,255]
        if 300 <= radius < 350:
            rainbow[rainbow.shape[1]//2 - i - 1,[rainbow.shape[1]//2 - j - 1,rainbow.shape[1]//2 + j - 1 ]] = [0,255,0]
        if 350 <= radius < 400:
            rainbow[rainbow.shape[1]//2 - i - 1,[rainbow.shape[1]//2 - j - 1,rainbow.shape[1]//2 + j - 1 ]] = [255,255,0]
        if 400 <= radius < 450:
            rainbow[rainbow.shape[1]//2 - i - 1,[rainbow.shape[1]//2 - j - 1,rainbow.shape[1]//2 + j - 1 ]] = [255,127,0]
        if 450 <= radius <= 500:
            rainbow[rainbow.shape[1]//2 - i - 1,[rainbow.shape[1]//2 - j - 1,rainbow.shape[1]//2 + j - 1 ]] = [255,0,0]
plt.imshow(rainbow)
plt.axis('off')
plt.show()

# %% [markdown]
# materwelon

# %%
image_waterwelon = cv2.imread('input\watermelon.jpg')
image_waterwelon = cv2.cvtColor(image_waterwelon, cv2.COLOR_BGR2RGB)
image_materwelon = image_waterwelon.copy()
for i in range(image_waterwelon.shape[0]):
    for j in range(image_waterwelon.shape[1]):
        if image_waterwelon[i, j, 2] < image_waterwelon[i, j, 0] > image_waterwelon[i, j, 1] :
            image_materwelon[i, j, 0] = image_waterwelon[i, j, 1]
            image_materwelon[i, j, 1] = image_waterwelon[i, j, 0]
        if image_waterwelon[i, j, 2] < image_waterwelon[i, j, 1] > image_waterwelon[i, j, 0] :
            image_materwelon[i, j, 0] = 255
            image_materwelon[i, j, 1] = abs(image_waterwelon[i, j, 0] - 20)
            image_materwelon[i, j, 2] = abs(image_waterwelon[i, j, 2] - 20)
            
plt.imshow(image_materwelon)
plt.axis('off')
plt.show()

# %% [markdown]
# rubic's cube

# %%
image_rubik = cv2.imread('input/rubik.jpg')
image_rubik = cv2.cvtColor(image_rubik, cv2.COLOR_BGR2RGB)
image_rubik_new = image_rubik.copy()
for i in range(image_rubik.shape[0]):
    for j in range(image_rubik.shape[1]):
        if image_rubik[i, j, 0] > 127 and image_rubik[i, j, 1] > 127 and image_rubik[i, j, 2] < 127:
            image_rubik_new[i, j] = [0, 0, 255]
        if image_rubik[i, j, 0] > 127 and image_rubik[i, j, 1] < 127 and image_rubik[i, j, 2] > 127:
            image_rubik_new[i, j] = [0, 255, 0]
        if image_rubik[i, j, 0] < 127 and image_rubik[i, j, 1] > 127 and image_rubik[i, j, 2] > 127:
            image_rubik_new[i, j] = [255, 0, 0]
            
plt.imshow(image_rubik_new)
plt.axis('off')
plt.show()

# %% [markdown]
# Microsoft logo

# %%
microsoft = np.ones((310,689,3), dtype=np.uint8)
microsoft[:,:,:] = [87, 83, 82]

microsoft[104:152, 104:152] = [242, 80, 34]
microsoft[157:206, 104:152] = [1, 164, 239]
microsoft[104:152, 157:206] = [127, 186, 0]
microsoft[157:206, 157:206] = [255, 185, 1]

image = Image.fromarray(microsoft)  

draw = ImageDraw.Draw(image)  
   
 # use a truetype font  
font = ImageFont.truetype('input\Segoe UI Bold.ttf', 77)

draw.text((236,100), "Microsoft", font=font)  

image.save("output/microsoft.png")
