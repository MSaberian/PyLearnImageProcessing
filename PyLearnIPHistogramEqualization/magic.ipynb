# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('input/1.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(image, cmap='gray')
plt.title('Orginal')
plt.show()

# %%
kernel = np.ones((5,5),np.float32)
result_5_1 = cv2.filter2D(image, -1, kernel)
plt.imshow(result_5_1, cmap='gray')
plt.title('Avg-Kernel 5x5 : 1.0')
plt.show()

# %%
kernel = np.ones((5,5),np.float32) * 0.04
result_5_4 = cv2.filter2D(image, -1, kernel)
plt.imshow(result_5_4, cmap='gray')
plt.title('Avg-Kernel 5x5 : 0.04')
plt.show()

# %%
kernel = np.ones((5,5),np.float32) * 5
result_5_5 = cv2.filter2D(image, -1, kernel)
plt.imshow(result_5_5, cmap='gray')
plt.title('Avg-Kernel 5x5 : 5.0')
plt.show()

# %%
kernel = np.ones((3,3),np.float32) * 0.04
result_3_4 = cv2.filter2D(image, -1, kernel)
plt.imshow(result_3_4, cmap='gray')
plt.title('Avg-Kernel 3x3 : 0.04')
plt.show()

# %%
kernel = np.ones((3,3),np.float32) * 1
result_3_1 = cv2.filter2D(image, -1, kernel)
plt.imshow(result_3_1, cmap='gray')
plt.title('Avg-Kernel 3x3 : 1.0')
plt.show()

# %%
kernel = np.ones((3,3),np.float32) * 5
result_3_5 = cv2.filter2D(image, -1, kernel)
plt.imshow(result_3_5, cmap='gray')
plt.title('Avg-Kernel 3x3 : 5.0')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.subplot(171)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title('Orginal')
plt.subplot(172)
plt.title('Avg-Kernel 5x5 : 0.04')
plt.imshow(result_5_4, cmap='gray')
plt.axis('off')
plt.subplot(173)
plt.title('Avg-Kernel 5x5 : 1')
plt.imshow(result_5_1, cmap='gray')
plt.axis('off')
plt.subplot(174)
plt.title('Avg-Kernel 5x5 : 5')
plt.imshow(result_5_5, cmap='gray')
plt.axis('off')
plt.subplot(175)
plt.title('Avg-Kernel 3x3 : 0.04')
plt.imshow(result_3_4, cmap='gray')
plt.axis('off')
plt.subplot(176)
plt.title('Avg-Kernel 3x3 : 1')
plt.imshow(result_3_1, cmap='gray')
plt.axis('off')
plt.subplot(177)
plt.title('Avg-Kernel 3x3 : 5')
plt.imshow(result_3_5, cmap='gray')
plt.axis('off')
plt.show()
