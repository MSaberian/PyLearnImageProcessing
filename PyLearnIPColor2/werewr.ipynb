# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('input\RGB.jpg')
image_2 = cv2.cvtColor(image, cv2.COLOR_RGB2HSV_FULL)
H, S, V = cv2.split(image_2)

# %%
plt.imshow(H, cmap='gray')
plt.axis('off')
plt.show()
