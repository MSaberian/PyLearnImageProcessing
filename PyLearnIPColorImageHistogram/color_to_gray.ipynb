# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
image = cv2.imread('input/emoji4.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
start_time = time.time()
R, G, B = cv2.split(image)
R = R.astype(float)
G = G.astype(float)
B = B.astype(float)

result = np.zeros(image.shape[0:2], dtype = np.uint8)

# result = (R + G + B)//3
# for i in range(image.shape[0]):
#     for j in range(image.shape[1]):
#         result[i, j] = (R[i, j] + G[i, j] + B[i, j])//3
result = np.mean(image, axis=2)

end_time = time.time()

print(end_time-start_time)

plt.imshow(result, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# 0.4643094539642334

# %%
image[30:70, 40:100, 3] = 0
image[100:130, 40:120, 3] = 127

cv2.imwrite('dasd.pnp', image)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 image[30:70, 40:100, 3] = 0
#       2 image[100:130, 40:120, 3] = 127
#       4 cv2.imwrite('dasd.pnp', image)
#
# IndexError: index 3 is out of bounds for axis 2 with size 3
